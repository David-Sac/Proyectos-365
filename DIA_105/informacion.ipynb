# %% [markdown]
# ## DIA 105: Conectar una Base de Datos PostgreSQL Remota a tu App Flask en Render

# %% [markdown]
# Ahora que tu app Flask está desplegada, el siguiente paso es conectar una base de datos en la nube para almacenar usuarios, registros, predicciones, etc.
#
# ✅ ¿Qué aprenderás hoy?
#
# 🛠️ Crear una base de datos PostgreSQL en Render.
#
# 🌐 Conectarla con SQLAlchemy.
#
# 🔐 Configurar las variables de entorno seguras.
#
# 🧩 1. Crear la Base de Datos PostgreSQL en Render
# Ve a https://dashboard.render.com
#
# Clic en "New +" → "PostgreSQL"
#
# Ponle un nombre (ej: predicciones-db)
#
# Espera a que Render la cree
#
# Copia la Database URL (lucirá así):
#
# bash
# Copiar
# Editar
# postgres://usuario:password@host:port/dbname
# 🧩 2. Añadir variable de entorno en Render
# En el panel de tu servicio Flask:
#
# Ve a Environment → Add Environment Variable
#
# Agrega:
#
# KEY: DATABASE_URL
#
# VALUE: la URL que copiaste
#
# 🧩 3. Configurar conexión en tu app.py
# Instala primero SQLAlchemy y psycopg2:
#
# bash
# Copiar
# Editar
# pip install flask-sqlalchemy psycopg2-binary
# Luego en tu app.py:
#
# python
# Copiar
# Editar
# from flask_sqlalchemy import SQLAlchemy
#
# app.config['SQLALCHEMY_DATABASE_URI'] = os.getenv("DATABASE_URL")
# app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
# db = SQLAlchemy(app)
# 🧩 4. Definir tus modelos
# python
# Copiar
# Editar
# class Registro(db.Model):
#     id = db.Column(db.Integer, primary_key=True)
#     fecha = db.Column(db.DateTime, default=datetime.utcnow)
#     f1 = db.Column(db.Float)
#     f2 = db.Column(db.Float)
#     f3 = db.Column(db.Float)
#     f4 = db.Column(db.Float)
#     prediccion = db.Column(db.String(10))
#     user_id = db.Column(db.Integer, db.ForeignKey('user.id'))
#
# class User(db.Model):
#     id = db.Column(db.Integer, primary_key=True)
#     email = db.Column(db.String(120), unique=True, nullable=False)
#     password = db.Column(db.String(120), nullable=False)
#     registros = db.relationship('Registro', backref='usuario', lazy=True)
# 🧩 5. Crear la base de datos (una sola vez)
# Haz esto en un entorno local o mediante SSH con Render:
#
# python
# Copiar
# Editar
# from app import db, app
#
# with app.app_context():
#     db.create_all()
# Si usas el entorno local, asegúrate de tener las mismas variables de entorno cargadas (DATABASE_URL).
